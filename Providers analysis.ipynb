# %%
import pandas as pd

prov = pd.read_csv('providers.csv')
prov['Funding'] = prov['2014-15 Australian Government Funding'].fillna(0).apply(lambda x: int(str(x).replace('n.a.','0').replace('$','').replace(',','')))
prov.head()
# Out:
#                       Service name Physical Address Line 1  \
# 0  3Bridges Community Incorporated      1/72 Carwar Avenue
# 1      501 Respite & Care Services     501 Pine Ridge Road
# 2                   70 Lowe Street          70 Lowe Street
# 3                    A H Orr Lodge      27 Clissold Street
# 4               A M Ramsay Village         77 Seaview Road
#
#   Physical Address Line 2 Physical Address Suburb Physical Address State  \
# 0                     NaN              CARSS PARK                    NSW
# 1                     NaN          BIGGERA WATERS                    QLD
# 2                     NaN                  ARARAT                    VIC
# 3                     NaN                ASHFIELD                    NSW
# 4                     NaN            PORT AUGUSTA                     SA
#
#    Physical Address Post Code 2015 Aged Care Planning Region (ACPR)  \
# 0                      2221.0                     South East Sydney
# ...

# %%
# Let's just look at residential care
resi = prov[(prov['Residential Places'].notnull())&(prov['Home Care Low Places'].isnull())\
            &(prov['Home Care High Places'].isnull())&(prov['Transition Care Places'].isnull())]
resi.sort_values('Residential Places')
# Out:
#                                            Service name  \
# 5120                     Willaura Hospital Nursing Home
# 4896                                            Veranto
# 3380                               Omeo District Health
# 1430               Childers Multipurpose Health Service
# 3194                                 MSV-Changing Needs
# 1596  Coober Pedy Hospital & Health Service Multipur...
# 2346                                      Hughenden MPS
# 1932  Far North Coast Disability and Aged Consortium...
# 3907                                        Rocky Ridge
# 141       Alpha and Jericho Multipurpose Health Service
# 2154                      Gulgong Multi-Purpose Service
# 1696            Dirranbandi Multipurpose Health Service
# 4535                        Surat Multi-purpose Service
# 5002  Waratah Respite Centre (Mid North Coast) Incor...
# 1537                              Collinsville Hospital
# 1984                       Flinders Ranges - Hawker MPS
# ...

# %%
resi.groupby('Physical Address State')[['Residential Places','Home Care Low Places','Home Care High Places','Transition Care Places','Funding']]\
.sum().sort('Residential Places',ascending=False)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                         Residential Places  Home Care Low Places  \
# Physical Address State
# NSW                                66759.0                   NaN
# VIC                                50978.0                   NaN
# QLD                                34588.0                   NaN
# SA                                 18172.0                   NaN
# WA                                 15707.0                   NaN
# TAS                                 4934.0                   NaN
# ACT                                 2247.0                   NaN
# NT                                   507.0                   NaN
#
#                         Home Care High Places  Transition Care Places  \
# Physical Address State
# NSW                                       NaN                     NaN
# ...

# %%
resi['$pp'] = resi['Funding'] / resi['Residential Places']
resi.groupby(['Organisation Type','Physical Address State'])[['Residential Places','Funding','$pp']]\
.sum()
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                                         Residential Places  \
# Organisation Type               Physical Address State
# Charitable                      ACT                                  734.0
#                                 NSW                                15985.0
#                                 NT                                    18.0
#                                 QLD                                 5576.0
#                                 SA                                  3842.0
#                                 TAS                                 1381.0
# ...

# %%
resi['$pp'] = (resi['Funding'] / resi['Residential Places']).astype(int)

resi.groupby(['Organisation Type'])[['Residential Places','Funding','$pp']]\
.sum().sort_values('$pp')
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                  Residential Places     Funding       $pp
# Organisation Type
# Private Non-Incorporated Entity                53.0     2797314     52779
# Publicly Listed Company                       186.0    12683374    119336
# Local Government                             1571.0    67316643   1519346
# State Government                             9138.0   444978069  14614066
# Community Based                             26540.0  1310007376  21417970
# Charitable                                  34444.0  1883274433  25769132
# ...

# %%
prov.sort_values('Funding')
# Out:
#                                            Service name  \
# 5233                                n.a.  Not Available
# 4159                Silver Chain South West HCP Level 3
# 4152        Silver Chain North Metropolitan HCP Level 2
# 5232                                                NaN
# 4150                  Silver Chain Mid West HCP Level 3
# 2661         KinCare - New England - home care packages
# 2689         KinCare At Home, QLD, Wide Bay - Home Care
# 4147            Silver Chain Great Southern HCP Level 3
# 3979    RSL Care WA Rural South West Home Care Packages
# 3911                                Roma Hospital - Ccp
# 881                 Blue Care Moura Community Care CACP
# 1230                                Care Connect - Hume
# 2891             Mackay Yamadi Lera Yumi Meta Assoc Inc
# 3626              Port Augusta Community Health Service
# 2924             Mapoon Home and Community Care Program
# 2946                           Marthakal Health Service
# ...
