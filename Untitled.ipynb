# %%
import pandas as pd

rooms = pd.read_csv('rooms.csv')

# %%
rooms.head()
# Out:
#    Unnamed: 0 Extra service  Maximum Room Occupancy  Number of Rooms of Type  \
# 0           0             N                       1                       20
# 1           1             N                       1                        6
# 2           2             N                       1                        8
# 3           3             N                       2                       14
# 4           4             N                       1                        0
#
#               Room Name               Room Size  exampleDAPDollar  \
# 0           Room Type A     Average size 14.5m2             43.02
# 1           Room Type B    Average size 12.6 m2             43.02
# 2           Room Type C    average size 11.88m2             43.02
# 3           Room Type D  Average size of 20.2m2             43.02
# 4  Lowe Street Single 1      3.90 square metres             25.81
#
#    exampleDAPPercentage  exampleRADDollar  exampleRADPercentage  \
# 0                    50            250000                    50
# 1                    50            250000                    50
# 2                    50            250000                    50
# 3                    50            250000                    50
# 4                    50            150000                    50
#
#    extraServiceFeesAmount                         home         iD  maximumDAP  \
# 0                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 1                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 2                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 3                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 4                     NaN               70 Lowe Street   1-E6-962       51.62
#
#    maximumRAD rADExceedsThresholdApproved serviceID  \
# 0      500000                          No   1-EP-49
# 1      500000                          No   1-EP-49
# 2      500000                          No   1-EP-49
# 3      500000                          No   1-EP-49
# 4      300000            Pending Approval  1-EP-393
#
#                   serviceSubType          suburb
# 0          Single room + ensuite  BIGGERA WATERS
# 1          Single room + ensuite  BIGGERA WATERS
# 2  Single room + shared bathroom  BIGGERA WATERS
# 3  Shared room + shared bathroom  BIGGERA WATERS
# 4          Single room + ensuite          ARARAT

# %%
gen = pd.read_csv('general.csv')
gen.head()
# Out:
#    Unnamed: 0 accreditationFlag accreditationPeriod availabilityFlag  \
# 0           0              True             3 Years             True
# 1           1              True             3 Years             True
# 2           2              True             3 Years             True
# 3           3              True             3 Years             True
# 4           4              True             3 Years             True
#
#   catersForDiverseNeedsFlag certification contactDetails_address_addressLine1  \
# 0                      True          True                501 PINE RIDGE Road
# 1                     False          True                     70 LOWE Street
# 2                      True          True                 31 CLISSOLD Street
# 3                     False         False                    77 SEAVIEW Road
# 4                      True          True                  376 WARRIGAL Road
#
#   contactDetails_address_country  \
# 0                      Australia
# 1                      Australia
# 2                      Australia
# 3                      Australia
# 4                      Australia
#
#    contactDetails_address_geoLocationDetails_latitude  \
# 0                                         -27.922204
# 1                                         -37.277969
# 2                                         -33.894955
# 3                                         -32.499665
# 4                                         -37.958560
#
#    contactDetails_address_geoLocationDetails_longitude  \
# 0                                         153.384513
# 1                                         142.932994
# 2                                         151.125841
# 3                                         137.781118
# 4                                         145.076137
#
#                  ...                 qIEnrolmentFlag rADApprovalDate  \
# 0                ...                           False             NaN
# 1                ...                           False             NaN
# 2                ...                           False             NaN
# 3                ...                           False             NaN
# 4                ...                           False             NaN
#
#   rADThresholdDate rADThresholdEffDate rADThresholdValue  sanctionFlag  \
# 0       2015-06-27          2015-01-01            550000         False
# 1       2015-06-27          2015-01-01            550000         False
# 2       2015-06-27          2015-01-01            550000         False
# 3       2015-06-27          2015-01-01            550000         False
# 4       2015-06-27          2015-01-01            550000         False
#
#              serviceType   startDate waitlistFlag  \
# 0  Residential Permanent  2003-04-23         True
# 1  Residential Permanent  1994-07-01         True
# 2  Residential Permanent  1989-01-11         True
# 3  Residential Permanent  1989-01-11         True
# 4  Residential Permanent  1989-01-11        False
#
#                          websiteURL
# 0             http://501care.com.au
# 1                               NaN
# 2          http://www.bethel.org.au
# 3  http://www.portaugusta.sa.gov.au
# 4              www.monashhealth.org
#
# [5 rows x 49 columns]

# %%
gen.head().transpose()
# Out:
#                                                                               0  \
# Unnamed: 0                                                                    0
# accreditationFlag                                                          True
# accreditationPeriod                                                     3 Years
# availabilityFlag                                                           True
# catersForDiverseNeedsFlag                                                  True
# certification                                                              True
# contactDetails_address_addressLine1                        501 PINE RIDGE Road
# contactDetails_address_country                                        Australia
# contactDetails_address_geoLocationDetails_latitude                     -27.9222
# contactDetails_address_geoLocationDetails_longi...                      153.385
# contactDetails_address_postcode                                            4216
# contactDetails_address_state                                                QLD
# contactDetails_address_suburb                                    BIGGERA WATERS
# contactDetails_contactName                                         Rachel Burke
# contactDetails_emailAddress                                 info@501care.com.au
# contactDetails_enquiryHours                                                 NaN
# contactDetails_faxNumber                                          +610755005026
# contactDetails_phoneNumber                                        +610755374278
# contactDetails_websiteURL                                                   NaN
# cultureSpiritualFoodRequirement                                             NaN
# description                                                                 NaN
# endDate                                                                     NaN
# facilityAddress_addressLine1                                                NaN
# facilityAddress_addressLine2                                501 PINE RIDGE Road
# facilityAddress_country                                                     NaN
# facilityAddress_postcode                                                   4216
# facilityAddress_state                                                       QLD
# facilityAddress_suburb                                           BIGGERA WATERS
# facilityName                                        501 Respite & Care Services
# fundedFlag                                                                 True
# iD                                                                      1-EP-49
# languages_language                                                          NaN
# locallyKnownAsName                                                          NaN
# mPIR                                                                       6.28
# mPIRPeriod                                                           2015-07-01
# nNCFlag                                                                   False
# outletID                                                              1-E6-2072
# outletName                                          501 Respite & Care Services
# previouslyKnownAsName                                                       NaN
# qIEnrolmentFlag                                                           False
# rADApprovalDate                                                             NaN
# rADThresholdDate                                                     2015-06-27
# rADThresholdEffDate                                                  2015-01-01
# rADThresholdValue                                                        550000
# sanctionFlag                                                              False
# serviceType                                               Residential Permanent
# startDate                                                            2003-04-23
# waitlistFlag                                                               True
# websiteURL                                                http://501care.com.au
#
#                                                                            1  \
# Unnamed: 0                                                                 1
# accreditationFlag                                                       True
# accreditationPeriod                                                  3 Years
# availabilityFlag                                                        True
# catersForDiverseNeedsFlag                                              False
# certification                                                           True
# contactDetails_address_addressLine1                          70 LOWE Street
# contactDetails_address_country                                     Australia
# contactDetails_address_geoLocationDetails_latitude                   -37.278
# contactDetails_address_geoLocationDetails_longi...                   142.933
# contactDetails_address_postcode                                         3377
# contactDetails_address_state                                             VIC
# contactDetails_address_suburb                                         ARARAT
# contactDetails_contactName                                      Fiona Miller
# contactDetails_emailAddress                         fiona.miller@eghs.net.au
# contactDetails_enquiryHours                                              NaN
# contactDetails_faxNumber                                                 NaN
# contactDetails_phoneNumber                                     +610353529316
# contactDetails_websiteURL                             http://www.eghs.net.au
# cultureSpiritualFoodRequirement                                          NaN
# description                                                              NaN
# endDate                                                                  NaN
# facilityAddress_addressLine1                                             NaN
# facilityAddress_addressLine2                                  70 LOWE Street
# facilityAddress_country                                                  NaN
# facilityAddress_postcode                                                3377
# facilityAddress_state                                                    VIC
# facilityAddress_suburb                                                ARARAT
# facilityName                                                  70 Lowe Street
# fundedFlag                                                              True
# iD                                                                  1-EP-393
# languages_language                                                       NaN
# locallyKnownAsName                                                       NaN
# mPIR                                                                    6.28
# mPIRPeriod                                                        2015-07-01
# nNCFlag                                                                False
# outletID                                                            1-E6-962
# outletName                                                    70 Lowe Street
# previouslyKnownAsName                                    John Pickford House
# qIEnrolmentFlag                                                        False
# rADApprovalDate                                                          NaN
# rADThresholdDate                                                  2015-06-27
# rADThresholdEffDate                                               2015-01-01
# rADThresholdValue                                                     550000
# sanctionFlag                                                           False
# serviceType                                            Residential Permanent
# startDate                                                         1994-07-01
# waitlistFlag                                                            True
# websiteURL                                                               NaN
#
#                                                                            2  \
# Unnamed: 0                                                                 2
# accreditationFlag                                                       True
# accreditationPeriod                                                  3 Years
# availabilityFlag                                                        True
# catersForDiverseNeedsFlag                                               True
# certification                                                           True
# contactDetails_address_addressLine1                      31 CLISSOLD Street
# contactDetails_address_country                                     Australia
# contactDetails_address_geoLocationDetails_latitude                   -33.895
# contactDetails_address_geoLocationDetails_longi...                   151.126
# contactDetails_address_postcode                                         2131
# contactDetails_address_state                                             NSW
# contactDetails_address_suburb                                       ASHFIELD
# contactDetails_contactName                                      Leigh Kildey
# contactDetails_emailAddress                            lkildey@bethel.org.au
# contactDetails_enquiryHours                                              NaN
# contactDetails_faxNumber                                       +610297998480
# contactDetails_phoneNumber                                     +610297973600
# contactDetails_websiteURL                                                NaN
# cultureSpiritualFoodRequirement                                          NaN
# description                                                              NaN
# endDate                                                                  NaN
# facilityAddress_addressLine1                                             NaN
# facilityAddress_addressLine2                              27 Clissold Street
# facilityAddress_country                                                  NaN
# facilityAddress_postcode                                                2131
# facilityAddress_state                                                    NSW
# facilityAddress_suburb                                              ASHFIELD
# facilityName                                                   A H Orr Lodge
# fundedFlag                                                              True
# iD                                                                 1-EP-1025
# languages_language                                                       NaN
# locallyKnownAsName                                              Not Supplied
# mPIR                                                                    6.28
# mPIRPeriod                                                        2015-07-01
# nNCFlag                                                                False
# outletID                                                             1-E6-10
# outletName                                                     A H Orr Lodge
# previouslyKnownAsName                                                    NaN
# qIEnrolmentFlag                                                        False
# rADApprovalDate                                                          NaN
# rADThresholdDate                                                  2015-06-27
# rADThresholdEffDate                                               2015-01-01
# rADThresholdValue                                                     550000
# sanctionFlag                                                           False
# serviceType                                            Residential Permanent
# startDate                                                         1989-01-11
# waitlistFlag                                                            True
# websiteURL                                          http://www.bethel.org.au
#
#                                                                                                     3  \
# Unnamed: 0                                                                                          3
# accreditationFlag                                                                                True
# accreditationPeriod                                                                           3 Years
# availabilityFlag                                                                                 True
# catersForDiverseNeedsFlag                                                                       False
# certification                                                                                   False
# contactDetails_address_addressLine1                                                  77 SEAVIEW Road
# contactDetails_address_country                                                              Australia
# contactDetails_address_geoLocationDetails_latitude                                           -32.4997
# contactDetails_address_geoLocationDetails_longi...                                            137.781
# contactDetails_address_postcode                                                                  5700
# contactDetails_address_state                                                                       SA
# contactDetails_address_suburb                                                            PORT AUGUSTA
# contactDetails_contactName                                                           Bernice Racanati
# contactDetails_emailAddress                                              ramsay@portaugusta.sa.gov.au
# contactDetails_enquiryHours                                                                       NaN
# contactDetails_faxNumber                                                                          NaN
# contactDetails_phoneNumber                                                              +610886426742
# contactDetails_websiteURL                            http://www.portaugusta.sa.gov.au/page.aspx?u=959
# cultureSpiritualFoodRequirement                                                                   NaN
# description                                         AM Ramsay Village is a 62 bed accredited and c...
# endDate                                                                                           NaN
# facilityAddress_addressLine1                                                                      NaN
# facilityAddress_addressLine2                                                          77 SEAVIEW Road
# facilityAddress_country                                                                           NaN
# facilityAddress_postcode                                                                         5700
# facilityAddress_state                                                                              SA
# facilityAddress_suburb                                                                   PORT AUGUSTA
# facilityName                                                                       A M Ramsay Village
# fundedFlag                                                                                       True
# iD                                                                                           1-1W8T68
# languages_language                                                                                NaN
# locallyKnownAsName                                                                       Not Supplied
# mPIR                                                                                             6.28
# mPIRPeriod                                                                                 2015-07-01
# nNCFlag                                                                                         False
# outletID                                                                                    1-E6-1545
# outletName                                                                         A M Ramsay Village
# previouslyKnownAsName                                                   A M Ramsay Retirement Village
# qIEnrolmentFlag                                                                                 False
# rADApprovalDate                                                                                   NaN
# rADThresholdDate                                                                           2015-06-27
# rADThresholdEffDate                                                                        2015-01-01
# rADThresholdValue                                                                              550000
# sanctionFlag                                                                                    False
# serviceType                                                                     Residential Permanent
# startDate                                                                                  1989-01-11
# waitlistFlag                                                                                     True
# websiteURL                                                           http://www.portaugusta.sa.gov.au
#
#                                                                                                     4
# Unnamed: 0                                                                                          4
# accreditationFlag                                                                                True
# accreditationPeriod                                                                           3 Years
# availabilityFlag                                                                                 True
# catersForDiverseNeedsFlag                                                                        True
# certification                                                                                    True
# contactDetails_address_addressLine1                                                376 WARRIGAL Road
# contactDetails_address_country                                                              Australia
# contactDetails_address_geoLocationDetails_latitude                                           -37.9586
# contactDetails_address_geoLocationDetails_longi...                                            145.076
# contactDetails_address_postcode                                                                  3192
# contactDetails_address_state                                                                      VIC
# contactDetails_address_suburb                                                              CHELTENHAM
# contactDetails_contactName                                                               Rhonda Wynne
# contactDetails_emailAddress                                             rhonda.wynne@monashhealth.org
# contactDetails_enquiryHours                                                                       NaN
# contactDetails_faxNumber                                                                          NaN
# contactDetails_phoneNumber                                                              +610392651784
# contactDetails_websiteURL                                                                         NaN
# cultureSpiritualFoodRequirement                                                                   NaN
# description                                         Eastwood Hostel is set in the Kingston Centre ...
# endDate                                                                                    2015-12-02
# facilityAddress_addressLine1                                                                      NaN
# facilityAddress_addressLine2                                                        376 WARRIGAL Road
# facilityAddress_country                                                                           NaN
# facilityAddress_postcode                                                                         3192
# facilityAddress_state                                                                             VIC
# facilityAddress_suburb                                                                     CHELTENHAM
# facilityName                                                                    A. G. Eastwood Hostel
# fundedFlag                                                                                       True
# iD                                                                                            1-B5-29
# languages_language                                                                                NaN
# locallyKnownAsName                                                                       Not Supplied
# mPIR                                                                                             6.28
# mPIRPeriod                                                                                 2015-07-01
# nNCFlag                                                                                         False
# outletID                                                                                      1-AU-58
# outletName                                                                      A. G. Eastwood Hostel
# previouslyKnownAsName                                                                             NaN
# qIEnrolmentFlag                                                                                 False
# rADApprovalDate                                                                                   NaN
# rADThresholdDate                                                                           2015-06-27
# rADThresholdEffDate                                                                        2015-01-01
# rADThresholdValue                                                                              550000
# sanctionFlag                                                                                    False
# serviceType                                                                     Residential Permanent
# startDate                                                                                  1989-01-11
# waitlistFlag                                                                                    False
# websiteURL                                                                       www.monashhealth.org

# %%
grant = pd.read_csv('2015round.csv')
grant.head()
# Out:
#   State/\rTerritory Region                                    Provider Name  \
# 0               ACT    ACT          Aged Care Services 45 (Woodend) Pty Ltd
# 1               ACT    ACT                       Bunyundah Nominees Pty Ltd
# 2               ACT    ACT  Morshead Home for Veterans and Aged Persons Inc
# 3               ACT    ACT                       Provectus Care Pty Limited
# 4               ACT    ACT                             RSL LifeCare Limited
#
#                            Service Name and Address* Places Allocated  \
# 0  New Service - 2015 - - Greenway\r60 Rowland Re...               90
# 1  Kankinya Aged Care Facility\r48 Archibald Stre...               12
# 2  Sir Leslie Morshead Manor\r26 Archibald Street...                5
# 3  New Service - 2015 - Belconnen Residential Age...               90
# 4  Bill McKenzie Gardens\r23 Burkitt Street\rPAGE...                5
#
#    Capital Grant
# 0               -
# 1               -
# 2               -
# 3               -
# 4               -

# %%
geo = gen[['contactDetails_address_geoLocationDetails_latitude','contactDetails_address_geoLocationDetails_longitude']]
geo.describe()
# Out:
#        contactDetails_address_geoLocationDetails_latitude  \
# count                                        1975.000000
# mean                                          -33.769384
# std                                             4.469318
# min                                           -43.314658
# 25%                                           -37.636197
# 50%                                           -33.977034
# 75%                                           -32.009865
# max                                           -10.574118
#
#        contactDetails_address_geoLocationDetails_longitude
# count                                        1975.000000
# mean                                          144.877544
# std                                             9.762871
# min                                           114.608310
# 25%                                           144.373851
# 50%                                           146.678615
# 75%                                           151.132693
# max                                           153.617837

# %%
names = gen[['facilityName','outletName']]
names['same'] = names['facilityName'] == names['outletName']
names
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                     facilityName  \
# 0                    501 Respite & Care Services
# 1                                 70 Lowe Street
# 2                                  A H Orr Lodge
# 3                             A M Ramsay Village
# 4                          A. G. Eastwood Hostel
# 5                  Abberfield Aged Care Facility
# 6                        Abbeyfield House Hostel
# 7                            Abel Tasman Village
# 8                         Abernethy Nursing Home
# 9                        Uniting Abrina Ashfield
# 10    Acacia House Residential Aged Care Service
# 11                             ACDMA Aged Hostel
# 12                                   Ada Cottage
# 13                          Adelene Court Hostel
# 14                          Adelene Nursing Home
# 15                             Adria Village Ltd
# 16               Advantaged Care at Barden Lodge
# 17              Advantaged Care at Georges Manor
# 18                            AdventCare Bendigo
# 19                AdventCare Whitehorse (Hostel)
# 20                       AdventCare Yarra Ranges
# 21                        Adventist Nursing Home
# 22                    Adventist Residential Care
# 23    Adventist Retirement Village - Victoria Pt
# 24                           Aegis Alfred Carson
# 25                                Aegis Amberley
# 26                               Aegis Anchorage
# 27                                Aegis Balmoral
# 28                            Aegis Banksia Park
# 29                              Aegis Bassendean
# ...                                          ...
# 2257                                   Woodhaven
# 2258                             Woodlands Lodge
# 2259                              Woodlands Park
# 2260          Woodlands Residential Care Service
# 2261              Woodport Aged Care Plus Centre
# 2262                       Woods Point Aged Care
# 2263                 Woolgoolga Aged Care Centre
# 2264                   Woollahra Montefiore Home
# 2265                                Woombye Care
# 2266                        Woorayl Lodge Hostel
# 2267                         Wynyard Care Centre
# 2268                        Wyoming Nursing Home
# 2269                  Yaandina Frail Aged Hostel
# 2270                        Yagoona Nursing Home
# 2271                       Baptistcare Yallambee
# 2272                             Yallambee Lodge
# 2273                             Yallambee Lodge
# 2274                           Yallambee Village
# 2275                              Yamaroo Hostel
# 2276                           Yankalilla Centre
# 2277                            Yaraandoo Hostel
# 2278                               Yaralla Place
# 2279                        Yarra West Aged Care
# 2280                       Yarraman Nursing Home
# 2281                   Yarriambiack Lodge Hostel
# 2282             Yarriambiack Lodge Nursing Home
# 2283                        Yeltana Nursing Home
# 2284               Yeoval Community Nursing Home
# 2285                          Zion Lutheran Home
# 2286                   Zion Lutheran Home Hostel
#
#                                             outletName   same
# 0                          501 Respite & Care Services   True
# 1                                       70 Lowe Street   True
# 2                                        A H Orr Lodge   True
# 3                                   A M Ramsay Village   True
# 4                                A. G. Eastwood Hostel   True
# 5                        Abberfield Aged Care Facility   True
# 6                                           Abbeyfield  False
# 7                                  Abel Tasman Village   True
# 8                               Abernethy Nursing Home   True
# 9                              Uniting Abrina Ashfield   True
# 10          Acacia House Residential Aged Care Service   True
# 11                                   ACDMA Aged Hostel   True
# 12                                         ADA Cottage  False
# 13                                Adelene Court Hostel   True
# 14                                Adelene Nursing Home   True
# 15                                   Adria Village Ltd   True
# 16                     Advantaged Care at Barden Lodge   True
# 17                    Advantaged Care at Georges Manor   True
# 18                                  AdventCare Bendigo   True
# 19                               AdventCare Whitehorse  False
# 20                             AdventCare Yarra Ranges   True
# 21                             Adventists Nursing Home  False
# 22                Adventist Residential Care-Rossmoyne  False
# 23          Adventist Retirement Village - Victoria Pt   True
# 24                                 Alfred Carson Lodge  False
# 25                                  Amberley Aged Care  False
# 26                                 Anchorage Aged Care  False
# 27                                  Balmoral Aged Care  False
# 28                              Banksia Park Aged Care  False
# 29                                Bassendean Aged Care  False
# ...                                                ...    ...
# 2257                                         Woodhaven   True
# 2258                               UPA Woodlands Lodge  False
# 2259                                    Woodlands Park   True
# 2260                Woodlands Residential Care Service   True
# 2261                    Woodport Aged Care Plus Centre   True
# 2262                             Woods Point Aged Care   True
# 2263                       Woolgoolga Aged Care Centre   True
# 2264                         Woollahra Montefiore Home   True
# 2265                                    Nangarin Lodge  False
# 2266                                 Woorayl Lodge Inc  False
# 2267                               Wynyard Care Centre   True
# 2268                              Wyoming Nursing Home   True
# 2269                         Yaandina Aged Care Centre  False
# 2270                              Yagoona Nursing Home   True
# 2271                          Baptistcare WA Yallambee  False
# 2272                                   Yallambee Lodge   True
# 2273                                   Yallambee Lodge   True
# 2274                                 Yallambee Village   True
# 2275                               Yackandandah Health  False
# 2276  ACH Group Yankalilla Centre Residential Services  False
# 2277                                  Yaraandoo Hostel   True
# 2278                          PresCare - Yaralla Place  False
# 2279                              Yarra West Aged Care   True
# 2280                             Yarraman Nursing Home   True
# 2281                         Yarriambiack Lodge Hostel   True
# 2282                   Yarriambiack Lodge Nursing Home   True
# 2283                              Yeltana Nursing Home   True
# 2284                     UPA Yeoval Aged Care Services  False
# 2285                                Zion Lutheran Home   True
# 2286                         Zion Lutheran Home Hostel   True
#
# [2287 rows x 3 columns]

# %%
names.groupby('same').count()
# Out:
#        facilityName  outletName
# same
# False           644         644
# True           1643        1643

# %%
grant.count()
# Out:
# State/\rTerritory            234
# Region                       232
# Provider Name                232
# Service Name and Address*    232
# Places Allocated             232
#  Capital Grant               232
# dtype: int64

# %%
rooms.head()
# Out:
#    Unnamed: 0 Extra service  Maximum Room Occupancy  Number of Rooms of Type  \
# 0           0             N                       1                       20
# 1           1             N                       1                        6
# 2           2             N                       1                        8
# 3           3             N                       2                       14
# 4           4             N                       1                        0
#
#               Room Name               Room Size  exampleDAPDollar  \
# 0           Room Type A     Average size 14.5m2             43.02
# 1           Room Type B    Average size 12.6 m2             43.02
# 2           Room Type C    average size 11.88m2             43.02
# 3           Room Type D  Average size of 20.2m2             43.02
# 4  Lowe Street Single 1      3.90 square metres             25.81
#
#    exampleDAPPercentage  exampleRADDollar  exampleRADPercentage  \
# 0                    50            250000                    50
# 1                    50            250000                    50
# 2                    50            250000                    50
# 3                    50            250000                    50
# 4                    50            150000                    50
#
#    extraServiceFeesAmount                         home         iD  maximumDAP  \
# 0                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 1                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 2                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 3                     NaN  501 Respite & Care Services  1-E6-2072       86.03
# 4                     NaN               70 Lowe Street   1-E6-962       51.62
#
#    maximumRAD rADExceedsThresholdApproved serviceID  \
# 0      500000                          No   1-EP-49
# 1      500000                          No   1-EP-49
# 2      500000                          No   1-EP-49
# 3      500000                          No   1-EP-49
# 4      300000            Pending Approval  1-EP-393
#
#                   serviceSubType          suburb
# 0          Single room + ensuite  BIGGERA WATERS
# 1          Single room + ensuite  BIGGERA WATERS
# 2  Single room + shared bathroom  BIGGERA WATERS
# 3  Shared room + shared bathroom  BIGGERA WATERS
# 4          Single room + ensuite          ARARAT

# %%
combo = pd.merge(rooms,gen,left_on='serviceID',right_on='iD')

# %%
combo['People'] = combo['Maximum Room Occupancy'] * combo['Number of Rooms of Type']

# %%
combo.groupby('contactDetails_address_state')['People'].sum()
# Out:
# contactDetails_address_state
# ACT      841
# NSW    30749
# NT        53
# QLD    12950
# SA      6834
# TAS     2479
# VIC    19644
# WA      7154
# Name: People, dtype: float64

# %%
rooms.columns
# Out:
# Index(['Unnamed: 0', 'Extra service', 'Maximum Room Occupancy',
#        'Number of Rooms of Type', 'Room Name', 'Room Size', 'exampleDAPDollar',
#        'exampleDAPPercentage', 'exampleRADDollar', 'exampleRADPercentage',
#        'extraServiceFeesAmount', 'home', 'iD', 'maximumDAP', 'maximumRAD',
#        'rADExceedsThresholdApproved', 'serviceID', 'serviceSubType', 'suburb',
#        'People'],
#       dtype='object')

# %%
# %pylab inline
for t in combo['']
combo['maximumRAD'].hist(bins=20)
# Out:
# Populating the interactive namespace from numpy and matplotlib
